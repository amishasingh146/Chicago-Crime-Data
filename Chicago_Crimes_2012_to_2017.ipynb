# %% [markdown]
# # Chicago Crime Dataset for year : 2012 - 2017

# %% [markdown]
# Ths is a exploratory data analysis for Chicago Crime Data. The data is taken from Kaggle.
#
# The data include 1,456,714 rows and following columns :
#
# __ID & Case number__: These are unique Ids/Primary Keys the crimes.
#
# __Date__: Date of the incident.
#
# __Block__: Block's name where the crime occured.
#
# __IUCR__: Illionis Uniform Crime reporting code is linked to the description of a crime.
#
# __Primary Type__: Primary description of crime according to IUCR.
#
# __Description__: Secondary description of crime according to IUCR.
#
# __Location Description__: Description of location where the incident occured.
#
# __Arrest__: Indicates whether or not an arrest was made.
#
# __Domestic__: Indicates whether the crime was domestic related or not.
#
# __Beat__: Indicates the beat where the incident/crime occured. A beat is a smallest police geographic area.
#
# __District & Ward__: Indicates district and ward where the incident occured.
#
# __Community area__: Indicates community area where the incident occured.
#
# __FBI Code__: Indicates crime classification code as per FBI.
#
# __X and Y co-ordinates__: Indicates X & Y co-ordinates of the location where the incident occured, respectively.
#
# __Year and Updated On__: Indicates time of when the incident occured, and when the incident report was last updated, respectively.
#
# __Latitude, Longitude & Location__: Indicates the latitude and longitude of location where the incident occured.

# %% [markdown]
# __Import libraries - Pandas, Numpy, Matplotlib and Seaborn__

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# __Read in Chicago Crime Dataset from Year 2012 to 2017__

# %%
chicago = pd.read_csv("Chicago_Crimes_2012_to_2017.csv" , index_col=0)
# Out:
# C:\Users\Amisha\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# __Show Top 5 rows__

# %%
chicago.head()
# Out:
#            ID Case Number                    Date                Block  IUCR  \
# 3    10508693    HZ250496  05/03/2016 11:40:00 PM   013XX S SAWYER AVE  0486
# 89   10508695    HZ250409  05/03/2016 09:40:00 PM   061XX S DREXEL AVE  0486
# 197  10508697    HZ250503  05/03/2016 11:31:00 PM  053XX W CHICAGO AVE  0470
# 673  10508698    HZ250424  05/03/2016 10:10:00 PM    049XX W FULTON ST  0460
# 911  10508699    HZ250455  05/03/2016 10:00:00 PM    003XX N LOTUS AVE  0820
#
#                Primary Type              Description Location Description  \
# 3                   BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT
# 89                  BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE
# 197  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT               STREET
# 673                 BATTERY                   SIMPLE             SIDEWALK
# 911                   THEFT           $500 AND UNDER            RESIDENCE
#
# ...

# %% [markdown]
# __Statistics of the data__

# %%
chicago.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  1.456714e+06  1.456714e+06  1.456713e+06  1.456700e+06    1.456674e+06
# mean   9.597550e+06  1.150644e+03  1.125920e+01  2.287027e+01    3.745632e+01
# std    8.083505e+05  6.916466e+02  6.904691e+00  1.380589e+01    2.144029e+01
# min    2.022400e+04  1.110000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    9.002709e+06  6.130000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    9.605776e+06  1.024000e+03  1.000000e+01  2.300000e+01    3.200000e+01
# 75%    1.022577e+07  1.711000e+03  1.700000e+01  3.400000e+01    5.600000e+01
# max    1.082788e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  1.419631e+06  1.419631e+06  1.456714e+06  1.419631e+06  1.419631e+06
# mean   1.164398e+06  1.885523e+06  2.013897e+03  4.184147e+01 -8.767224e+01
# ...

# %% [markdown]
# __Drop unwanted columns__

# %%
chicago_new = chicago.drop(['ID','Case Number','Date','IUCR','FBI Code'],axis=1)
chicago_new.head()
# Out:
#                    Block            Primary Type              Description  \
# 3     013XX S SAWYER AVE                 BATTERY  DOMESTIC BATTERY SIMPLE
# 89    061XX S DREXEL AVE                 BATTERY  DOMESTIC BATTERY SIMPLE
# 197  053XX W CHICAGO AVE  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 673    049XX W FULTON ST                 BATTERY                   SIMPLE
# 911    003XX N LOTUS AVE                   THEFT           $500 AND UNDER
#
#     Location Description  Arrest  Domestic  Beat  District  Ward  \
# 3              APARTMENT    True      True  1022      10.0  24.0
# 89             RESIDENCE   False      True   313       3.0  20.0
# 197               STREET   False     False  1524      15.0  37.0
# 673             SIDEWALK   False     False  1532      15.0  28.0
# 911            RESIDENCE   False      True  1523      15.0  28.0
#
#      Community Area  X Coordinate  Y Coordinate  Year              Updated On  \
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# __Arresets made per year__

# %%
Arrests = chicago_new['Arrest'].groupby(chicago_new['Year']).sum()
DataFrame(Arrests)
# Out:
#        Arrest
# Year
# 2012  90511.0
# 2013  86219.0
# 2014  79057.0
# 2015  69397.0
# 2016  50386.0
# 2017   1902.0

# %% [markdown]
# __Domestic Crimes occured per Year__

# %%
Domestic = chicago_new['Domestic'].groupby(chicago_new['Year']).sum()
DataFrame(Domestic)
# Out:
#       Domestic
# Year
# 2012   48521.0
# 2013   44839.0
# 2014   40398.0
# 2015   41677.0
# 2016   42787.0
# 2017    1832.0

# %% [markdown]
# __Top 10 Primary Type of Arrests__

# %%
Arrests = chicago_new['Arrest'].groupby(chicago_new['Primary Type']).sum()
DataFrame(Arrests.sort_values(ascending = False).head(10))
# Out:
#                           Arrest
# Primary Type
# NARCOTICS               134317.0
# BATTERY                  60501.0
# THEFT                    36673.0
# CRIMINAL TRESPASS        25927.0
# ASSAULT                  21348.0
# OTHER OFFENSE            18573.0
# WEAPONS VIOLATION        13746.0
# CRIMINAL DAMAGE          10165.0
# PUBLIC PEACE VIOLATION    9949.0
# DECEPTIVE PRACTICE        8917.0

# %% [markdown]
# __Top 10 Crime Location__

# %%
Arrests = chicago_new['Arrest'].groupby(chicago_new['Location Description']).sum()
DataFrame(Arrests.sort_values(ascending=False).head(10))
# Out:
#                                  Arrest
# Location Description
# STREET                          83646.0
# SIDEWALK                        77486.0
# APARTMENT                       31365.0
# RESIDENCE                       29372.0
# ALLEY                           14867.0
# DEPARTMENT STORE                11837.0
# PARKING LOT/GARAGE(NON.RESID.)   9690.0
# VEHICLE NON-COMMERCIAL           8906.0
# GROCERY FOOD STORE               8536.0
# SMALL RETAIL STORE               8236.0

# %% [markdown]
# __Top 10 Districts where Arrests were made__

# %%
Arrests = chicago_new['Arrest'].groupby(chicago_new['District']).sum()
DataFrame(Arrests.sort_values(ascending = False).head(10))
# Out:
#            Arrest
# District
# 11.0      45042.0
# 7.0       25820.0
# 15.0      24370.0
# 6.0       23766.0
# 25.0      22902.0
# 8.0       22730.0
# 4.0       20435.0
# 10.0      20402.0
# 9.0       18627.0
# 3.0       18514.0

# %% [markdown]
# __Number of times no one was arrested__

# %%
len(chicago_new[chicago_new.Arrest != True])
# Out:
# 1079242

# %% [markdown]
# # Data Visualization

# %% [markdown]
# __Arrests per Year__

# %%
ArrestPerYear = chicago_new['Arrest'].groupby(chicago_new['Year']).sum()
ArrestPerYear = DataFrame(ArrestPerYear)
ArrestPerYear = ArrestPerYear.reset_index()

plt.bar(ArrestPerYear['Year'],ArrestPerYear['Arrest'])
plt.show()

# %% [markdown]
# __Arrests per Primary Type__

# %%
ArrestPerType = chicago_new['Arrest'].groupby(chicago_new['Primary Type']).sum()
ArrestPerType = DataFrame(ArrestPerType.sort_values(ascending = False).head(5))
ArrestPerType = ArrestPerType.reset_index()


plt.bar(ArrestPerType['Primary Type'],ArrestPerType['Arrest'])
plt.rcParams['figure.figsize'] = [22, 12]
plt.show()

# %% [markdown]
# __This is a very nice dataset to work with.It has intresting fields and it is better to look at both the tables and the charts for Exploratory Data Analysis.Thank You for viewing :) __
